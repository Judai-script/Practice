# %%
import pandas as pd
from alpha_vantage.fundamentaldata import FundamentalData

# %%
df = pd.read_csv("C:/Users/patel/Downloads/data/survey_results_public.csv")
key_path = "C:/Users/patel/OneDrive/Desktop/top secret.txt"
with open(key_path, "r") as f:
    key = f.read()
    key = key[23:]

AVobj = FundamentalData(key=key, output_format="pandas")

# %%
pd.set_option("display.max_columns", 38)
pd.set_option("display.max_rows", 100)

# %%
balsheet= AVobj.get_balance_sheet_annual(symbol="msft")

# %%
balsheetDF = balsheet[0]
display(balsheetDF.shape)
display(balsheetDF.info())
display(balsheetDF)
# Out:
# (15, 38)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15 entries, 1970-01-01 00:00:00 to 1970-01-01 00:00:00.000000014
# Data columns (total 38 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   fiscalDateEnding                        15 non-null     object
#  1   reportedCurrency                        15 non-null     object
#  2   totalAssets                             15 non-null     object
#  3   totalCurrentAssets                      15 non-null     object
#  4   cashAndCashEquivalentsAtCarryingValue   15 non-null     object
#  5   cashAndShortTermInvestments             15 non-null     object
#  6   inventory                               15 non-null     object
#  7   currentNetReceivables                   15 non-null     object
#  8   totalNonCurrentAssets                   15 non-null     object
# ...

# %%
v1=balsheetDF[["fiscalDateEnding","totalAssets", "totalLiabilities", "deferredRevenue"]]
display(v1)
display(balsheetDF.iloc[[0,2,3],[2,3,4]])
balsheetDF.index
balsheetDF.loc[["1970-01-01 00:00:00.000000000","1970-01-01 00:00:00.000000001"],["fiscalDateEnding"]]
# Out:
#                               fiscalDateEnding   totalAssets totalLiabilities  \
# date
# 1970-01-01 00:00:00.000000000       2023-06-30  411976000000     205753000000
# 1970-01-01 00:00:00.000000001       2022-06-30  364840000000     198298000000
# 1970-01-01 00:00:00.000000002       2021-06-30  333779000000     191791000000
# 1970-01-01 00:00:00.000000003       2020-06-30  301311000000     183007000000
# 1970-01-01 00:00:00.000000004       2019-06-30  286556000000     184226000000
# 1970-01-01 00:00:00.000000005       2018-06-30  258848000000     176130000000
# 1970-01-01 00:00:00.000000006       2017-06-30  250312000000     162601000000
# 1970-01-01 00:00:00.000000007       2016-06-30  193468000000     121471000000
# 1970-01-01 00:00:00.000000008       2015-06-30  174472000000      94389000000
# 1970-01-01 00:00:00.000000009       2014-06-30  172384000000      82600000000
# 1970-01-01 00:00:00.000000010       2013-06-30  142431000000      63487000000
# ...

# %%
dict={"name":["john","setra","batman"],
      "title":["doe","the imperishable","defender of gotham"]}
df1 = pd.DataFrame(dict)
display(df1)
# Out:
#      name               title
# 0    john                 doe
# 1   setra    the imperishable
# 2  batman  defender of gotham

# %%
lst1 = [1,2,3,4,5]
srs1 = pd.Series(lst1)
srs1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
balsheetDFI = balsheetDF.set_index("fiscalDateEnding")
balsheetDFI
# Out:
#                  reportedCurrency   totalAssets totalCurrentAssets  \
# fiscalDateEnding
# 2023-06-30                    USD  411976000000       184257000000
# 2022-06-30                    USD  364840000000       169684000000
# 2021-06-30                    USD  333779000000       184406000000
# 2020-06-30                    USD  301311000000       181915000000
# 2019-06-30                    USD  286556000000       175552000000
# 2018-06-30                    USD  258848000000       169662000000
# 2017-06-30                    USD  250312000000       162696000000
# 2016-06-30                    USD  193468000000       139660000000
# 2015-06-30                    USD  174472000000       122797000000
# 2014-06-30                    USD  172384000000       114246000000
# 2013-06-30                    USD  142431000000       101466000000
# 2012-06-30                    USD  121271000000        85084000000
# 2011-06-30                    USD  108704000000        74918000000
# ...
